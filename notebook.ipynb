# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/train2.csv', dtype={"district_id": "Int64", "city_id": "Int64", "id": "Int64", "is_business": "string", "region_id": "Int64", "price": "Int64", "created_at_first": "str",
"params": "str"}, engine="python", encoding="utf-8")

# %%
districts = pd.read_csv("data/districts.csv", dtype={'id': 'Int64'})

# %%
cities = pd.read_csv("data/cities.csv", dtype={'id': 'Int64'})

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
df.head()
# Out:
#    Unnamed: 0      id     created_at_first                category  \
# 0           0  325017  2018-10-06 12:20:48  Mieszkanie na sprzedaż
# 1           1  513427  2019-02-18 12:17:51  Mieszkanie na sprzedaż
# 2           2  824979  2019-03-21 17:31:09  Mieszkanie na sprzedaż
# 3           3  400727  2018-11-28 23:50:45  Mieszkanie na sprzedaż
# 4           4  298324  2019-01-22 21:22:42         Dom na sprzedaż
#
#   is_business  district_id  city_id  region_id  \
# 0           1        12867      210         14
# 1           1         <NA>     3614         15
# 2           1         3434      204         10
# 3           1           87        1         15
# 4           0         <NA>    11879          7
#
#                                               params   price
# 0  price[currency]<=>PLN<br>m<=>72.14<br>rooms_nu...  389556
# 1  price[currency]<=>PLN<br>m<=>95<br>rooms_num<=...  500000
# 2  price[currency]<=>PLN<br>m<=>58.9<br>rooms_num...  238000
# 3  price[currency]<=>PLN<br>m<=>45<br>rooms_num<=...  209000
# 4  price[currency]<=>PLN<br>terrain_area<=>3201<b...  729000

# %%
def merge_drop_rename(df, cities, districts):
    data = pd.merge(df, cities, left_on="city_id", right_on="id") #merging data with cities
    data = data.drop("id_y", axis=1) #dropping trash column
    districts = districts.rename(columns={"id": "district_id"})
    data = pd.merge(data, districts, on="district_id", how="left") #merging data (now data with cities) with districts
    data = data.drop(columns = {"Unnamed: 0", "id_x", "created_at_first", "region_id", "lon_x", "lat_x", "city_id", "district_id", "lon_y", "lat_y"}) #dropping trash columns
    data = data.rename(columns = {"name_pl_x": "city_name", "name_pl_y": "district_name"})
    return data

# %%
def parse_values(row):
    pairs = row.split('<br>') #creating a pair of col_name and value
    values = {}
    for pair in pairs: #going through pairs of col_name and value
        if pair.strip() != '': 
            col, val = pair.split('<=>') #splitting a pair for col_name and value
            if val.strip() == '' or val.strip().lower() == 'nan':
                val = np.nan #filling with NaNs
            values[col] = val #putting values into columns
    return pd.Series(values)

# %%
def parse_extras(row):
    row = str(row) #for some reason it wasn't a string
    pairs = row.split('<->') #splitting extras
    values = {}
    for pair in pairs:
        if pair.strip() != '' and pair.strip() != 'nan' and pair.strip() != "0":
            col = pair
            val = True #assigning value
        else:
            col = "trash"
            val = np.nan
        values[col] = val #putting values into columns
    return pd.Series(values)

# %%
data = merge_drop_rename(df, cities, districts)
parsed_data = data['params'].apply(parse_values).apply(pd.Series) #extracting params

# %%
parsed_data.head()
# Out:
#   price[currency]      m rooms_num     market building_type      floor_no  \
# 0             PLN  72.14         4  secondary           NaN       floor_1
# 1             PLN     95         4  secondary        ribbon  ground_floor
# 2             PLN   58.9         3  secondary         block       floor_3
# 3             PLN     45         2  secondary           NaN  ground_floor
# 4             PLN    195         6  secondary      detached           NaN
#
#   building_floors_num building_material windows_type heating build_year  \
# 0                   1               NaN      plastic     NaN       2018
# 1                   1             brick      plastic     gas       2014
# 2                   4    concrete_plate       wooden   urban       1986
# 3                 NaN               NaN      plastic     NaN        NaN
# 4                 NaN             brick      plastic     NaN       2015
#
#   construction_status rent rent[currency] building_ownership free_from  \
# 0                 NaN  NaN            PLN                NaN       NaN
# 1        ready_to_use  NaN            PLN     full_ownership       NaN
# 2       to_renovation  430            PLN     full_ownership       NaN
# 3                 NaN  320            PLN                NaN       NaN
# 4        ready_to_use  NaN            PLN                NaN       NaN
#
#                                  media_types  \
# 0                                        NaN
# 1        cable-television<->internet<->phone
# 2                cable-television<->internet
# 3                                        NaN
# 4  cesspool<->electricity<->internet<->water
#
#                                       security_types  \
# 0                                                NaN
# 1                      closed_area<->roller_shutters
# 2                                         entryphone
# 3                                                NaN
# 4  alarm<->anti_burglary_door<->closed_area<->ent...
#
#                                      equipment_types  \
# 0                                                NaN
# 1  dishwasher<->fridge<->oven<->stove<->washing_m...
# 2                              fridge<->oven<->stove
# 3                                                NaN
# 4                                                NaN
#
#                                         extras_types terrain_area floors_num  \
# 0                                            balcony          NaN        NaN
# 1  garage<->garden<->terrace<->two_storey<->usabl...          NaN        NaN
# 2              balcony<->basement<->separate_kitchen          NaN        NaN
# 3                                           basement          NaN        NaN
# 4                              attic<->garage<->pool         3201  one_floor
#
#   garret_type roof_type roofing location recreational fence_types  \
# 0         NaN       NaN     NaN      NaN          NaN         NaN
# 1         NaN       NaN     NaN      NaN          NaN         NaN
# 2         NaN       NaN     NaN      NaN          NaN         NaN
# 3         NaN       NaN     NaN      NaN          NaN         NaN
# 4      usable  diagonal   sheet  country            0        wire
#
#   heating_types access_types vicinity_types is_bungalow use_types type  \
# 0           NaN          NaN            NaN         NaN       NaN  NaN
# 1           NaN          NaN            NaN         NaN       NaN  NaN
# 2           NaN          NaN            NaN         NaN       NaN  NaN
# 3           NaN          NaN            NaN         NaN       NaN  NaN
# 4          coal      asphalt         forest           0       NaN  NaN
#
#   dimensions fence  deposit deposit[currency] rent_to_students
# 0        NaN   NaN      NaN               NaN              NaN
# 1        NaN   NaN      NaN               NaN              NaN
# 2        NaN   NaN      NaN               NaN              NaN
# 3        NaN   NaN      NaN               NaN              NaN
# 4        NaN   NaN      NaN               NaN              NaN

# %%
set(parsed_data["use_types"])
# Out:
# {'0', 'gastronomy<->hotel', nan, 'office'}

# %%
data = merge_drop_rename(df, cities, districts)
#data = data.loc[data['city_name'] == "Lublin"] #filtering data for a given city
parsed_data = data['params'].apply(parse_values).apply(pd.Series) #extracting params
#parsed_data = parsed_data.drop(["free_from", "building_ownership", "price[currency]", "rent[currency]", "use_types", "type", "dimensions", "fence", "deposit", "deposit[currency]", "rent_to_students"], axis=1)
columns_to_drop = ["construction_status", "free_from", "building_ownership", "price[currency]", "rent[currency]", "use_types", "type", "dimensions", "fence", "deposit", "deposit[currency]", "rent_to_students"]
existing_columns = [col for col in columns_to_drop if col in parsed_data.columns]
parsed_data = parsed_data.drop(columns=existing_columns)
to_parse = ["media_types", "security_types", "equipment_types", "extras_types"]
for column in to_parse:
    parsed_col = parsed_data[column].apply(parse_extras).apply(pd.Series) # for parsing extras_types 
    parsed_data = pd.concat([parsed_data, parsed_col], axis=1)
    parsed_data = parsed_data.drop(column, axis=1)
parsed_data = parsed_data.drop(["trash"], axis=1) #droping trash column from extras_type
#parsed_data = parsed_data.replace(np.nan, False)

# %%
parsed_data.head()
# Out:
#          m rooms_num     market building_type floor_no building_floors_num  \
# 19    57.1         3  secondary         block  floor_3                   5
# 25   84.68         4  secondary         block  floor_3                   4
# 250     52         2  secondary         block  floor_2                   3
# 260  30.62         2    primary     apartment  floor_2                   7
# 262     46         3  secondary         block  floor_4                   4
#
#     building_material windows_type heating build_year   rent terrain_area  \
# 19              False      plastic   urban       1995    400        False
# 25              False        False   urban       2001    500        False
# 250             False      plastic   urban       2008    280        False
# 260             False      plastic   urban       2020     50        False
# 262    concrete_plate      plastic   urban       1979  369.7        False
#
#     floors_num garret_type roof_type roofing location recreational  \
# 19       False       False     False   False    False        False
# 25       False       False     False   False    False        False
# 250      False       False     False   False    False        False
# 260      False       False     False   False    False        False
# 262      False       False     False   False    False        False
#
#     fence_types heating_types access_types vicinity_types is_bungalow  \
# 19        False         False        False          False       False
# 25        False         False        False          False       False
# 250       False         False        False          False       False
# 260       False         False        False          False       False
# 262       False         False        False          False       False
#
#      cable-television  internet  phone  electricity  cable_television    gas  \
# 19               True      True   True        False             False  False
# 25               True      True   True        False             False  False
# 250             False     False   True        False             False  False
# 260             False     False  False        False             False  False
# 262              True      True   True        False             False  False
#
#      water  sewage  cesspool  water_purification  entryphone  \
# 19   False   False     False               False        True
# 25   False   False     False               False       False
# 250  False   False     False               False        True
# 260  False   False     False               False       False
# 262  False   False     False               False       False
#
#      anti_burglary_door  alarm  closed_area  monitoring  roller_shutters  \
# 19                False  False        False       False            False
# 25                False  False        False       False            False
# 250                True  False        False       False            False
# 260               False  False        False       False            False
# 262               False  False        False       False            False
#
#      fridge  furniture   oven  stove  washing_machine  dishwasher     tv  \
# 19     True       True   True   True             True       False  False
# 25    False      False  False  False            False       False  False
# 250    True      False   True  False             True        True  False
# 260   False      False  False  False            False       False  False
# 262   False      False  False  False            False       False  False
#
#      balcony  basement  garage  separate_kitchen   lift  garden  terrace  \
# 19      True      True    True              True  False   False    False
# 25      True      True   False             False  False   False    False
# 250     True      True   False             False  False   False    False
# 260     True     False    True             False   True   False    False
# 262    False      True   False             False  False   False    False
#
#      two_storey  usable_room  air_conditioning  attic   pool
# 19        False        False             False  False  False
# 25        False        False             False  False  False
# 250       False        False             False  False  False
# 260       False        False             False  False  False
# 262       False        False             False  False  False

# %%
len(parsed_data)
# Out:
# 12448

# %%
parsed_data.isnull().sum()/len(parsed_data)*100
# Out:
# m                       0.000000
# rooms_num               0.056234
# market                  0.000000
# building_type          28.390103
# floor_no               12.901671
# building_floors_num    14.227185
# building_material      55.117288
# windows_type           14.484254
# heating                35.475578
# build_year             11.294987
# rent                   56.675771
# terrain_area           89.926093
# floors_num             91.556877
# garret_type            98.080013
# roof_type              98.152314
# roofing                94.521208
# location               97.622108
# recreational           97.589974
# fence_types            95.163882
# heating_types          95.212082
# access_types           92.135283
# vicinity_types         97.830977
# is_bungalow            89.355720
# cable-television       64.299486
# internet               56.820373
# phone                  67.432519
# electricity            93.741967
# cable_television       99.397494
# gas                    93.444730
# water                  95.236183
# sewage                 95.975257
# cesspool               98.762853
# water_purification     99.783098
# entryphone             79.908419
# anti_burglary_door     90.392031
# alarm                  97.734576
# closed_area            94.697943
# monitoring             87.781170
# roller_shutters        99.397494
# fridge                 93.436697
# furniture              90.271530
# oven                   92.448586
# stove                  91.436375
# washing_machine        94.963046
# dishwasher             96.039524
# tv                     98.706620
# balcony                35.684447
# basement               48.674486
# garage                 57.655848
# separate_kitchen       76.486183
# lift                   57.446979
# garden                 95.179949
# terrace                90.962404
# two_storey             98.859254
# usable_room            95.228149
# air_conditioning       98.192481
# attic                  99.068123
# pool                   99.983933
# dtype: float64

# %%
data.head()
# Out:
#                  category is_business  \
# 0  Mieszkanie na sprzedaż           1
# 1  Mieszkanie na sprzedaż           1
# 2  Mieszkanie na sprzedaż           1
# 3  Mieszkanie na sprzedaż           1
# 4         Dom na sprzedaż           0
#
#                                               params   price  city_name  \
# 0  price[currency]<=>PLN<br>m<=>72.14<br>rooms_nu...  389556    Olsztyn
# 1  price[currency]<=>PLN<br>m<=>95<br>rooms_num<=...  500000   Plewiska
# 2  price[currency]<=>PLN<br>m<=>58.9<br>rooms_num...  238000  Białystok
# 3  price[currency]<=>PLN<br>m<=>45<br>rooms_num<=...  209000     Poznań
# 4  price[currency]<=>PLN<br>terrain_area<=>3201<b...  729000    Wymysły
#
#      district_name
# 0           Dajtki
# 1              NaN
# 2  Zielone Wzgórza
# 3           Łazarz
# 4              NaN

# %%
def parse_values(row):
    pairs = row.split('<br>') #creating a pair of col_name and value
    values = {}
    for pair in pairs: #going through pairs of col_name and value
        if pair.strip() != '': 
            col, val = pair.split('<=>') #splitting a pair for col_name and value
            if val.strip() == '' or val.strip().lower() == 'nan':
                val = np.nan #filling with NaNs
            values[col] = val #putting values into columns
    return pd.Series(values)

# %%
def merge_drop_rename(df, cities, districts):
    data = pd.merge(df, cities, left_on="city_id", right_on="id") #merging data with cities
    data = data.drop("id_y", axis=1) #dropping trash column
    districts = districts.rename(columns={"id": "district_id"})
    data = pd.merge(data, districts, on="district_id", how="left") #merging data (now data with cities) with districts
    data = data.drop(columns = {"Unnamed: 0", "id_x", "created_at_first", "region_id", "lon_x", "lat_x", "city_id", "district_id", "lon_y", "lat_y"}) #dropping trash columns
    data = data.rename(columns = {"name_pl_x": "city_name", "name_pl_y": "district_name"})
    return data
